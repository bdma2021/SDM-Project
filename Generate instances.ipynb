# %% [markdown]
# # SDM: Generate knowledge graph CSVs

# %%
import pandas as pd
import datetime as dt
import pyarrow as pa
import pyarrow.fs
import pyarrow.parquet
from itertools import count
from hdfs import InsecureClient

# %%
# Get datasources
datasource_df = pd.read_csv("data/datasource.csv")
datasource_df
# Out:
#      id                                           baseurl      label  \
# 0  ds_0                             https://api.gbif.org/       gbif
# 1  ds_1  https://neo.gsfc.nasa.gov/archive/geotiff.float/        neo
# 2  ds_2        https://biogeo.ucdavis.edu/data/worldclim/  worldclim
#
#                                              comment
# 0  GBIF—the Global Biodiversity Information Facil...
# 1  One of the best places to study Earth is from ...
# 2  WorldClim is a database of high spatial resolu...

# %%
# Setup HDFS client
client = InsecureClient("http://localhost:9870", user="bdm")

# List all existing files (file.csv: id,url,format,version,timestamp,datasource,label,comment)
fileIdGen = ("file_" + str(c) for c in count())
persistent_dir = "/user/bdm/persistent/"
files = []

# GBIF
gbif_ds = datasource_df[datasource_df["label"] == "gbif"].id.to_list()[0]
gbif_version = "1"
gbif_format = "PARQUET"
gbif_filename = "occurrence"
gbif_timestamps_dir = persistent_dir + "gbif/{}/".format(gbif_version)
gbif_timestamps = client.list(gbif_timestamps_dir)
for ts in gbif_timestamps:
    for download_key in client.list(gbif_timestamps_dir + ts):
        files.append({
            "id": fileIdGen.__next__(),
            "url": gbif_timestamps_dir + ts + "/" + download_key + "/" + gbif_filename + ".parquet",
            "format": gbif_format,
            "version": gbif_version,
            "timestamp": dt.datetime.strptime(ts, '%Y-%m-%d_%H-%M-%S'),
            "datasource": gbif_ds,
            "label": gbif_filename,
            "comment": "Download key: " + download_key,
        })
        
# NEO
neo_ds = datasource_df[datasource_df["label"] == "neo"].id.to_list()[0]
neo_version = None
neo_format = "PARQUET"
neo_datasets = client.list(persistent_dir + "neo/")
for ds in neo_datasets:
    neo_timestamps_dir = persistent_dir + "neo/" + ds + "/"
    neo_timestamps = client.list(neo_timestamps_dir)
    for ts in neo_timestamps:
        for filename in client.list(neo_timestamps_dir + ts):
            if ds == 'SRTM_RAMP2_TOPO':
                raster_date = dt.datetime.strptime(filename, '%Y.pq')
            else:
                raster_date = dt.datetime.strptime(filename, '%Y-%m.pq')
            files.append({
                "id": fileIdGen.__next__(),
                "url": neo_timestamps_dir + ts + "/" + filename,
                "format": neo_format,
                "version": neo_version,
                "timestamp": dt.datetime.strptime(ts, '%Y-%m-%d_%H-%M-%S'),
                "datasource": neo_ds,
                "label": "{} ({})".format(ds, raster_date.strftime("%Y-%m")),
                "comment": "Date: " + str(raster_date),
            })

# WorldClim
worldclim_ds = datasource_df[datasource_df["label"] == "worldclim"].id.to_list()[0]
worldclim_version = "2.1"
worldclim_format = "PARQUET"
worldclim_timestamps_dir = persistent_dir + "worldclim/{}/".format(worldclim_version)
worldclim_timestamps = client.list(worldclim_timestamps_dir)
for ts in worldclim_timestamps:
    for res in client.list(worldclim_timestamps_dir + ts):
        for var in client.list(worldclim_timestamps_dir + ts + "/" + res):
            for filename in client.list(worldclim_timestamps_dir + ts + "/" + res + "/" + var):
                if filename.endswith(".pq"):
                    worldclim_format = "PARQUET"
                elif filename.endswith(".tif"):
                    worldclim_format = "TIF"
                files.append({
                    "id": fileIdGen.__next__(),
                    "url": worldclim_timestamps_dir + ts + "/" + res + "/" + var + "/" + filename,
                    "format": worldclim_format,
                    "version": worldclim_version,
                    "timestamp": dt.datetime.strptime(ts, '%Y-%m-%d_%H-%M-%S'),
                    "datasource": worldclim_ds,
                    "label": "{} ({})".format(var, filename.split('.')[0]),
                    "comment": "Resolution: {}".format(res),
                })
      
files_df = pd.DataFrame(data=files)
files_df.to_csv("data/file.csv", index=False, header=True)
files_df
# Out:
#              id                                                url   format  \
# 0        file_0  /user/bdm/persistent/gbif/1/2022-05-11_13-04-4...  PARQUET
# 1        file_1  /user/bdm/persistent/gbif/1/2022-05-11_13-10-5...  PARQUET
# 2        file_2  /user/bdm/persistent/gbif/1/2022-05-11_13-11-5...  PARQUET
# 3        file_3  /user/bdm/persistent/gbif/1/2022-05-11_13-12-5...  PARQUET
# 4        file_4  /user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11...  PARQUET
# ...         ...                                                ...      ...
# 3288  file_3288  /user/bdm/persistent/worldclim/2.1/2022-06-02_...      TIF
# 3289  file_3289  /user/bdm/persistent/worldclim/2.1/2022-06-02_...  PARQUET
# 3290  file_3290  /user/bdm/persistent/worldclim/2.1/2022-06-02_...      TIF
# 3291  file_3291  /user/bdm/persistent/worldclim/2.1/2022-06-02_...  PARQUET
# 3292  file_3292  /user/bdm/persistent/worldclim/2.1/2022-06-02_...      TIF
#
#      version           timestamp datasource                 label  \
# 0          1 2022-05-11 13:04:40       ds_0            occurrence
# 1          1 2022-05-11 13:10:57       ds_0            occurrence
# 2          1 2022-05-11 13:11:51       ds_0            occurrence
# 3          1 2022-05-11 13:12:51       ds_0            occurrence
# 4       None 2022-05-11 13:21:07       ds_1  MOD_LSTD_M (2000-02)
# ...      ...                 ...        ...                   ...
# 3288     2.1 2022-06-02 11:35:08       ds_2             wind (10)
# 3289     2.1 2022-06-02 11:35:08       ds_2             wind (11)
# 3290     2.1 2022-06-02 11:35:08       ds_2             wind (11)
# 3291     2.1 2022-06-02 11:35:08       ds_2             wind (12)
# 3292     2.1 2022-06-02 11:35:08       ds_2             wind (12)
#
#                                     comment
# 0     Download key: 0273021-210914110416597
# 1     Download key: 0203956-210914110416597
# 2     Download key: 0204028-210914110416597
# 3     Download key: 0273021-210914110416597
# 4                 Date: 2000-02-01 00:00:00
# ...                                     ...
# 3288                         Resolution: 5m
# 3289                         Resolution: 5m
# 3290                         Resolution: 5m
# 3291                         Resolution: 5m
# 3292                         Resolution: 5m
#
# [3293 rows x 8 columns]

# %%
# Setup pyarrow
import os
import subprocess

os.environ["HADOOP_HOME"] = "/home/bdm/BDM_Software/hadoop"
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64/"
os.environ["CLASSPATH"] = str(subprocess.check_output(['{}/bin/hadoop'.format(os.environ["HADOOP_HOME"]), 'classpath', '--glob']))

# %%
# Create spark session and set up the database driver
from pyspark.sql import SparkSession
spark = (SparkSession
         .builder
         .config("spark.jars", "/usr/local/postgresql-42.2.5.jar")
         .master("local")
         .appName("species_rasters")
         .enableHiveSupport()
         .getOrCreate())

# %%
# List file attributes (attribute.csv: id,file,relatedattr,label,comment)

hdfs_base = "hdfs://pikachu.fib.upc.es:27000"

attributes = []
attrIdGen = ("attribute_" + str(c) for c in count())

files = files_df.loc[files_df.format == "PARQUET", ["id", "url"]]
for _, file in files.iterrows():
    print("Processing {} ({})".format(file["id"], file["url"]))
    try:
        df = spark.read.parquet(hdfs_base + file["url"])
        for attr in df.columns:
            attributes.append({
                "id": attrIdGen.__next__(),
                "file": file["id"],
                "relatedattr": None,
                "label": attr,
                "comment": None,
            })
    except:
        print("Failed to read file schema of " + file["id"])

attributes_df = pd.DataFrame(data=attributes)
attributes_df.to_csv("data/attribute.csv", index=False, header=True)
attributes_df
# Out:
# Processing file_0 (/user/bdm/persistent/gbif/1/2022-05-11_13-04-40/0273021-210914110416597/occurrence.parquet)
# Processing file_1 (/user/bdm/persistent/gbif/1/2022-05-11_13-10-57/0203956-210914110416597/occurrence.parquet)
# Processing file_2 (/user/bdm/persistent/gbif/1/2022-05-11_13-11-51/0204028-210914110416597/occurrence.parquet)
# Processing file_3 (/user/bdm/persistent/gbif/1/2022-05-11_13-12-51/0273021-210914110416597/occurrence.parquet)
# Processing file_4 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-02.pq)
# Processing file_5 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-03.pq)
# Processing file_6 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-04.pq)
# Processing file_7 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-05.pq)
# Processing file_8 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-06.pq)
# Processing file_9 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-07.pq)
# Processing file_10 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-08.pq)
# Processing file_11 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-09.pq)
# Processing file_12 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-10.pq)
# Processing file_13 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-11.pq)
# Processing file_14 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2000-12.pq)
# Processing file_15 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-01.pq)
# Processing file_16 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-02.pq)
# Processing file_17 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-03.pq)
# Processing file_18 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-04.pq)
# Processing file_19 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-05.pq)
# Processing file_20 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-06.pq)
# Processing file_21 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-07.pq)
# Processing file_22 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-08.pq)
# Processing file_23 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-09.pq)
# Processing file_24 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-10.pq)
# Processing file_25 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-11.pq)
# Processing file_26 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2001-12.pq)
# Processing file_27 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-01.pq)
# Processing file_28 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-02.pq)
# Processing file_29 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-03.pq)
# Processing file_30 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-04.pq)
# Processing file_31 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-05.pq)
# Processing file_32 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-06.pq)
# Processing file_33 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-07.pq)
# Processing file_34 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-08.pq)
# Processing file_35 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-09.pq)
# Processing file_36 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-10.pq)
# Processing file_37 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-11.pq)
# Processing file_38 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2002-12.pq)
# Processing file_39 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-01.pq)
# Processing file_40 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-02.pq)
# Processing file_41 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-03.pq)
# Processing file_42 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-04.pq)
# Processing file_43 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-05.pq)
# Processing file_44 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-06.pq)
# Processing file_45 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-07.pq)
# Processing file_46 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-08.pq)
# Processing file_47 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-09.pq)
# Processing file_48 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-10.pq)
# Processing file_49 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-11.pq)
# Processing file_50 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2003-12.pq)
# Processing file_51 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-01.pq)
# Processing file_52 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-02.pq)
# Processing file_53 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-03.pq)
# Processing file_54 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-04.pq)
# Processing file_55 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-05.pq)
# Processing file_56 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-06.pq)
# Processing file_57 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-07.pq)
# Processing file_58 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-08.pq)
# Processing file_59 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-09.pq)
# Processing file_60 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-10.pq)
# Processing file_61 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-11.pq)
# Processing file_62 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2004-12.pq)
# Processing file_63 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-01.pq)
# Processing file_64 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-02.pq)
# Processing file_65 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-03.pq)
# Processing file_66 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-04.pq)
# Processing file_67 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-05.pq)
# Processing file_68 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-06.pq)
# Processing file_69 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-07.pq)
# Processing file_70 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-08.pq)
# Processing file_71 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-09.pq)
# Processing file_72 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-10.pq)
# Processing file_73 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-11.pq)
# Processing file_74 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2005-12.pq)
# Processing file_75 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-01.pq)
# Processing file_76 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-02.pq)
# Processing file_77 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-03.pq)
# Processing file_78 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-04.pq)
# Processing file_79 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-05.pq)
# Processing file_80 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-06.pq)
# Processing file_81 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-07.pq)
# Processing file_82 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-08.pq)
# Processing file_83 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-09.pq)
# Processing file_84 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-10.pq)
# Processing file_85 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-11.pq)
# Processing file_86 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2006-12.pq)
# Processing file_87 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-01.pq)
# Processing file_88 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-02.pq)
# Processing file_89 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-03.pq)
# Processing file_90 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-04.pq)
# Processing file_91 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-05.pq)
# Processing file_92 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-06.pq)
# Processing file_93 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-07.pq)
# Processing file_94 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-08.pq)
# Processing file_95 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-09.pq)
# Processing file_96 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-10.pq)
# Processing file_97 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-11.pq)
# Processing file_98 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2007-12.pq)
# Processing file_99 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-01.pq)
# Processing file_100 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-02.pq)
# Processing file_101 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-03.pq)
# Processing file_102 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-04.pq)
# Processing file_103 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-05.pq)
# Processing file_104 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-06.pq)
# Processing file_105 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-07.pq)
# Processing file_106 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-08.pq)
# Processing file_107 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-09.pq)
# Processing file_108 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-10.pq)
# Processing file_109 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-11.pq)
# Processing file_110 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2008-12.pq)
# Processing file_111 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-01.pq)
# Processing file_112 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-02.pq)
# Processing file_113 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-03.pq)
# Processing file_114 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-04.pq)
# Processing file_115 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-05.pq)
# Processing file_116 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-06.pq)
# Processing file_117 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-07.pq)
# Processing file_118 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-08.pq)
# Processing file_119 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-09.pq)
# Processing file_120 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-10.pq)
# Processing file_121 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-11.pq)
# Processing file_122 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2009-12.pq)
# Processing file_123 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-01.pq)
# Processing file_124 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-02.pq)
# Processing file_125 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-03.pq)
# Processing file_126 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-04.pq)
# Processing file_127 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-05.pq)
# Processing file_128 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-06.pq)
# Processing file_129 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-07.pq)
# Processing file_130 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-08.pq)
# Processing file_131 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-09.pq)
# Processing file_132 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-10.pq)
# Processing file_133 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-11.pq)
# Processing file_134 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2010-12.pq)
# Processing file_135 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-01.pq)
# Processing file_136 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-02.pq)
# Processing file_137 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-03.pq)
# Processing file_138 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-04.pq)
# Processing file_139 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-05.pq)
# Processing file_140 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-06.pq)
# Processing file_141 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-07.pq)
# Processing file_142 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-08.pq)
# Processing file_143 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-09.pq)
# Processing file_144 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-10.pq)
# Processing file_145 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-11.pq)
# Processing file_146 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2011-12.pq)
# Processing file_147 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-01.pq)
# Processing file_148 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-02.pq)
# Processing file_149 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-03.pq)
# Processing file_150 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-04.pq)
# Processing file_151 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-05.pq)
# Processing file_152 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-06.pq)
# Processing file_153 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-07.pq)
# Processing file_154 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-08.pq)
# Processing file_155 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-09.pq)
# Processing file_156 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-10.pq)
# Processing file_157 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-11.pq)
# Processing file_158 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2012-12.pq)
# Processing file_159 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-01.pq)
# Processing file_160 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-02.pq)
# Processing file_161 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-03.pq)
# Processing file_162 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-04.pq)
# Processing file_163 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-05.pq)
# Processing file_164 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-06.pq)
# Processing file_165 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-07.pq)
# Processing file_166 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-08.pq)
# Processing file_167 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-09.pq)
# Processing file_168 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-10.pq)
# Processing file_169 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-11.pq)
# Processing file_170 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2013-12.pq)
# Processing file_171 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-01.pq)
# Processing file_172 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-02.pq)
# Processing file_173 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-03.pq)
# Processing file_174 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-04.pq)
# Processing file_175 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-05.pq)
# Processing file_176 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-06.pq)
# Processing file_177 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-07.pq)
# Processing file_178 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-08.pq)
# Processing file_179 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-09.pq)
# Processing file_180 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-10.pq)
# Processing file_181 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-11.pq)
# Processing file_182 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2014-12.pq)
# Processing file_183 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-01.pq)
# Processing file_184 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-02.pq)
# Processing file_185 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-03.pq)
# Processing file_186 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-04.pq)
# Processing file_187 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-05.pq)
# Processing file_188 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-06.pq)
# Processing file_189 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-07.pq)
# Processing file_190 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-08.pq)
# Processing file_191 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-09.pq)
# Processing file_192 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-10.pq)
# Processing file_193 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-11.pq)
# Processing file_194 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2015-12.pq)
# Processing file_195 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-01.pq)
# Processing file_196 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-02.pq)
# Processing file_197 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-03.pq)
# Processing file_198 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-04.pq)
# Processing file_199 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-05.pq)
# Processing file_200 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-06.pq)
# Processing file_201 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-07.pq)
# Processing file_202 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-08.pq)
# Processing file_203 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-09.pq)
# Processing file_204 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-10.pq)
# Processing file_205 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-11.pq)
# Processing file_206 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2016-12.pq)
# Processing file_207 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-01.pq)
# Processing file_208 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-02.pq)
# Processing file_209 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-03.pq)
# Processing file_210 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-04.pq)
# Processing file_211 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-05.pq)
# Processing file_212 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-06.pq)
# Processing file_213 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-07.pq)
# Processing file_214 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-08.pq)
# Processing file_215 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-09.pq)
# Processing file_216 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-10.pq)
# Processing file_217 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-11.pq)
# Processing file_218 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2017-12.pq)
# Processing file_219 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-01.pq)
# Processing file_220 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-02.pq)
# Processing file_221 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-03.pq)
# Processing file_222 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-04.pq)
# Processing file_223 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-05.pq)
# Processing file_224 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-06.pq)
# Processing file_225 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-07.pq)
# Processing file_226 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-08.pq)
# Processing file_227 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-09.pq)
# Processing file_228 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-10.pq)
# Processing file_229 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-11.pq)
# Processing file_230 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2018-12.pq)
# Processing file_231 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-01.pq)
# Processing file_232 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-02.pq)
# Processing file_233 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-03.pq)
# Processing file_234 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-04.pq)
# Processing file_235 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-05.pq)
# Processing file_236 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-06.pq)
# Processing file_237 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-07.pq)
# Processing file_238 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-08.pq)
# Processing file_239 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-09.pq)
# Processing file_240 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-10.pq)
# Processing file_241 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-11.pq)
# Processing file_242 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2019-12.pq)
# Processing file_243 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-01.pq)
# Processing file_244 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-02.pq)
# Processing file_245 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-03.pq)
# Processing file_246 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-04.pq)
# Processing file_247 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-05.pq)
# Processing file_248 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-06.pq)
# Processing file_249 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-07.pq)
# Processing file_250 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-08.pq)
# Processing file_251 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-09.pq)
# Processing file_252 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-10.pq)
# Processing file_253 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-11.pq)
# Processing file_254 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2020-12.pq)
# Processing file_255 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-01.pq)
# Processing file_256 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-02.pq)
# Processing file_257 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-03.pq)
# Processing file_258 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-04.pq)
# Processing file_259 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-05.pq)
# Processing file_260 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-06.pq)
# Processing file_261 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-07.pq)
# Processing file_262 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-08.pq)
# Processing file_263 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-09.pq)
# Processing file_264 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-10.pq)
# Processing file_265 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-11.pq)
# Processing file_266 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2021-12.pq)
# Processing file_267 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2022-01.pq)
# Processing file_268 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-11_13-21-07/2022-02.pq)
# Processing file_269 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-02.pq)
# Processing file_270 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-03.pq)
# Processing file_271 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-04.pq)
# Processing file_272 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-05.pq)
# Processing file_273 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-06.pq)
# Processing file_274 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-07.pq)
# Processing file_275 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-08.pq)
# Processing file_276 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-09.pq)
# Processing file_277 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-10.pq)
# Processing file_278 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-11.pq)
# Processing file_279 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2000-12.pq)
# Processing file_280 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-01.pq)
# Processing file_281 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-02.pq)
# Processing file_282 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-03.pq)
# Processing file_283 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-04.pq)
# Processing file_284 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-05.pq)
# Processing file_285 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-06.pq)
# Processing file_286 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-07.pq)
# Processing file_287 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-08.pq)
# Processing file_288 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-09.pq)
# Processing file_289 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-10.pq)
# Processing file_290 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-11.pq)
# Processing file_291 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2001-12.pq)
# Processing file_292 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-01.pq)
# Processing file_293 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-02.pq)
# Processing file_294 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-03.pq)
# Processing file_295 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-04.pq)
# Processing file_296 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-05.pq)
# Processing file_297 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-06.pq)
# Processing file_298 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-07.pq)
# Processing file_299 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-08.pq)
# Processing file_300 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-09.pq)
# Processing file_301 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-10.pq)
# Processing file_302 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-11.pq)
# Processing file_303 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2002-12.pq)
# Processing file_304 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-01.pq)
# Processing file_305 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-02.pq)
# Processing file_306 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-03.pq)
# Processing file_307 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-04.pq)
# Processing file_308 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-05.pq)
# Processing file_309 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-06.pq)
# Processing file_310 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-07.pq)
# Processing file_311 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-08.pq)
# Processing file_312 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-09.pq)
# Processing file_313 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-10.pq)
# Processing file_314 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-11.pq)
# Processing file_315 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2003-12.pq)
# Processing file_316 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-01.pq)
# Processing file_317 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-02.pq)
# Processing file_318 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-03.pq)
# Processing file_319 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-04.pq)
# Processing file_320 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-05.pq)
# Processing file_321 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-06.pq)
# Processing file_322 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-07.pq)
# Processing file_323 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-08.pq)
# Processing file_324 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-09.pq)
# Processing file_325 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-10.pq)
# Processing file_326 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-11.pq)
# Processing file_327 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2004-12.pq)
# Processing file_328 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-01.pq)
# Processing file_329 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-02.pq)
# Processing file_330 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-03.pq)
# Processing file_331 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-04.pq)
# Processing file_332 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-05.pq)
# Processing file_333 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-06.pq)
# Processing file_334 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-07.pq)
# Processing file_335 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-08.pq)
# Processing file_336 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-09.pq)
# Processing file_337 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-10.pq)
# Processing file_338 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-11.pq)
# Processing file_339 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2005-12.pq)
# Processing file_340 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-01.pq)
# Processing file_341 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-02.pq)
# Processing file_342 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-03.pq)
# Processing file_343 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-04.pq)
# Processing file_344 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-05.pq)
# Processing file_345 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-06.pq)
# Processing file_346 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-07.pq)
# Processing file_347 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-08.pq)
# Processing file_348 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-09.pq)
# Processing file_349 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-10.pq)
# Processing file_350 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-11.pq)
# Processing file_351 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2006-12.pq)
# Processing file_352 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-01.pq)
# Processing file_353 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-02.pq)
# Processing file_354 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-03.pq)
# Processing file_355 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-04.pq)
# Processing file_356 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-05.pq)
# Processing file_357 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-06.pq)
# Processing file_358 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-07.pq)
# Processing file_359 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-08.pq)
# Processing file_360 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-09.pq)
# Processing file_361 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-10.pq)
# Processing file_362 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-11.pq)
# Processing file_363 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2007-12.pq)
# Processing file_364 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-01.pq)
# Processing file_365 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-02.pq)
# Processing file_366 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-03.pq)
# Processing file_367 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-04.pq)
# Processing file_368 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-05.pq)
# Processing file_369 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-06.pq)
# Processing file_370 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-07.pq)
# Processing file_371 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-08.pq)
# Processing file_372 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-09.pq)
# Processing file_373 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-10.pq)
# Processing file_374 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-11.pq)
# Processing file_375 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2008-12.pq)
# Processing file_376 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-01.pq)
# Processing file_377 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-02.pq)
# Processing file_378 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-03.pq)
# Processing file_379 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-04.pq)
# Processing file_380 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-05.pq)
# Processing file_381 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-06.pq)
# Processing file_382 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-07.pq)
# Processing file_383 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-08.pq)
# Processing file_384 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-09.pq)
# Processing file_385 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-10.pq)
# Processing file_386 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-11.pq)
# Processing file_387 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2009-12.pq)
# Processing file_388 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-01.pq)
# Processing file_389 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-02.pq)
# Processing file_390 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-03.pq)
# Processing file_391 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-04.pq)
# Processing file_392 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-05.pq)
# Processing file_393 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-06.pq)
# Processing file_394 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-07.pq)
# Processing file_395 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-08.pq)
# Processing file_396 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-09.pq)
# Processing file_397 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-10.pq)
# Processing file_398 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-11.pq)
# Processing file_399 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2010-12.pq)
# Processing file_400 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-01.pq)
# Processing file_401 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-02.pq)
# Processing file_402 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-03.pq)
# Processing file_403 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-04.pq)
# Processing file_404 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-05.pq)
# Processing file_405 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-06.pq)
# Processing file_406 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-07.pq)
# Processing file_407 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-08.pq)
# Processing file_408 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-09.pq)
# Processing file_409 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-10.pq)
# Processing file_410 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-11.pq)
# Processing file_411 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2011-12.pq)
# Processing file_412 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-01.pq)
# Processing file_413 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-02.pq)
# Processing file_414 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-03.pq)
# Processing file_415 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-04.pq)
# Processing file_416 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-05.pq)
# Processing file_417 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-06.pq)
# Processing file_418 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-07.pq)
# Processing file_419 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-08.pq)
# Processing file_420 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-09.pq)
# Processing file_421 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-10.pq)
# Processing file_422 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-11.pq)
# Processing file_423 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2012-12.pq)
# Processing file_424 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-01.pq)
# Processing file_425 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-02.pq)
# Processing file_426 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-03.pq)
# Processing file_427 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-04.pq)
# Processing file_428 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-05.pq)
# Processing file_429 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-06.pq)
# Processing file_430 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-07.pq)
# Processing file_431 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-08.pq)
# Processing file_432 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-09.pq)
# Processing file_433 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-10.pq)
# Processing file_434 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-11.pq)
# Processing file_435 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2013-12.pq)
# Processing file_436 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-01.pq)
# Processing file_437 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-02.pq)
# Processing file_438 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-03.pq)
# Processing file_439 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-04.pq)
# Processing file_440 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-05.pq)
# Processing file_441 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-06.pq)
# Processing file_442 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-07.pq)
# Processing file_443 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-08.pq)
# Processing file_444 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-09.pq)
# Processing file_445 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-10.pq)
# Processing file_446 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-11.pq)
# Processing file_447 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2014-12.pq)
# Processing file_448 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-01.pq)
# Processing file_449 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-02.pq)
# Processing file_450 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-03.pq)
# Processing file_451 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-04.pq)
# Processing file_452 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-05.pq)
# Processing file_453 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-06.pq)
# Processing file_454 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-07.pq)
# Processing file_455 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-08.pq)
# Processing file_456 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-09.pq)
# Processing file_457 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-10.pq)
# Processing file_458 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-11.pq)
# Processing file_459 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2015-12.pq)
# Processing file_460 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-01.pq)
# Processing file_461 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-02.pq)
# Processing file_462 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-03.pq)
# Processing file_463 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-04.pq)
# Processing file_464 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-05.pq)
# Processing file_465 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-06.pq)
# Processing file_466 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-07.pq)
# Processing file_467 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-08.pq)
# Processing file_468 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-09.pq)
# Processing file_469 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-10.pq)
# Processing file_470 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-11.pq)
# Processing file_471 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2016-12.pq)
# Processing file_472 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-01.pq)
# Processing file_473 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-02.pq)
# Processing file_474 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-03.pq)
# Processing file_475 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-04.pq)
# Processing file_476 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-05.pq)
# Processing file_477 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-06.pq)
# Processing file_478 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-07.pq)
# Processing file_479 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-08.pq)
# Processing file_480 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-09.pq)
# Processing file_481 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-10.pq)
# Processing file_482 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-11.pq)
# Processing file_483 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2017-12.pq)
# Processing file_484 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-01.pq)
# Processing file_485 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-02.pq)
# Processing file_486 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-03.pq)
# Processing file_487 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-04.pq)
# Processing file_488 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-05.pq)
# Processing file_489 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-06.pq)
# Processing file_490 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-07.pq)
# Processing file_491 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-08.pq)
# Processing file_492 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-09.pq)
# Processing file_493 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-10.pq)
# Processing file_494 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-11.pq)
# Processing file_495 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2018-12.pq)
# Processing file_496 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-01.pq)
# Processing file_497 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-02.pq)
# Processing file_498 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-03.pq)
# Processing file_499 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-04.pq)
# Processing file_500 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-05.pq)
# Processing file_501 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-06.pq)
# Processing file_502 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-07.pq)
# Processing file_503 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-08.pq)
# Processing file_504 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-09.pq)
# Processing file_505 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-10.pq)
# Processing file_506 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-11.pq)
# Processing file_507 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2019-12.pq)
# Processing file_508 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-01.pq)
# Processing file_509 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-02.pq)
# Processing file_510 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-03.pq)
# Processing file_511 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-04.pq)
# Processing file_512 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-05.pq)
# Processing file_513 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-06.pq)
# Processing file_514 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-07.pq)
# Processing file_515 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-08.pq)
# Processing file_516 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-09.pq)
# Processing file_517 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-10.pq)
# Processing file_518 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-11.pq)
# Processing file_519 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2020-12.pq)
# Processing file_520 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-01.pq)
# Processing file_521 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-02.pq)
# Processing file_522 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-03.pq)
# Processing file_523 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-04.pq)
# Processing file_524 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-05.pq)
# Processing file_525 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-06.pq)
# Processing file_526 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-07.pq)
# Processing file_527 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-08.pq)
# Processing file_528 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-09.pq)
# Processing file_529 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-10.pq)
# Processing file_530 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-11.pq)
# Processing file_531 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2021-12.pq)
# Processing file_532 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2022-01.pq)
# Processing file_533 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-05-23_01-43-51/2022-02.pq)
# Processing file_534 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-06-02_11-36-26/2000-02.pq)
# Processing file_535 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-06-02_11-36-26/2000-03.pq)
# Processing file_536 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-06-02_11-36-26/2000-04.pq)
# Processing file_537 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-06-02_11-36-26/2000-05.pq)
# Processing file_538 (/user/bdm/persistent/neo/MOD_LSTD_M/2022-06-02_11-39-47/2000-02.pq)
# ...
# Processing file_2965 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/01.pq)
# Processing file_2967 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/02.pq)
# Processing file_2969 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/03.pq)
# Processing file_2971 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/04.pq)
# Processing file_2973 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/05.pq)
# Processing file_2975 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/06.pq)
# Processing file_2977 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/07.pq)
# Processing file_2979 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/08.pq)
# Processing file_2981 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/09.pq)
# Processing file_2983 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/10.pq)
# Processing file_2985 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/11.pq)
# Processing file_2987 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tavg/12.pq)
# Processing file_2989 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/01.pq)
# Processing file_2991 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/02.pq)
# Processing file_2993 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/03.pq)
# Processing file_2995 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/04.pq)
# Processing file_2997 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/05.pq)
# Processing file_2999 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/06.pq)
# Processing file_3001 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/07.pq)
# Processing file_3003 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/08.pq)
# Processing file_3005 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/09.pq)
# Processing file_3007 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/10.pq)
# Processing file_3009 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/11.pq)
# Processing file_3011 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmax/12.pq)
# Processing file_3013 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/01.pq)
# Processing file_3015 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/02.pq)
# Processing file_3017 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/03.pq)
# Processing file_3019 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/04.pq)
# Processing file_3021 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/05.pq)
# Processing file_3023 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/06.pq)
# Processing file_3025 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/07.pq)
# Processing file_3027 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/08.pq)
# Processing file_3029 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/09.pq)
# Processing file_3031 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/10.pq)
# Processing file_3033 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/11.pq)
# Processing file_3035 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/tmin/12.pq)
# Processing file_3037 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/01.pq)
# Processing file_3039 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/02.pq)
# Processing file_3041 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/03.pq)
# Processing file_3043 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/04.pq)
# Processing file_3045 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/05.pq)
# Processing file_3047 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/06.pq)
# Processing file_3049 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/07.pq)
# Processing file_3051 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/08.pq)
# Processing file_3053 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/09.pq)
# Processing file_3055 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/10.pq)
# Processing file_3057 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/11.pq)
# Processing file_3059 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/vapr/12.pq)
# Processing file_3061 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/01.pq)
# Processing file_3063 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/02.pq)
# Processing file_3065 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/03.pq)
# Processing file_3067 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/04.pq)
# Processing file_3069 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/05.pq)
# Processing file_3071 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/06.pq)
# Processing file_3073 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/07.pq)
# Processing file_3075 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/08.pq)
# Processing file_3077 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/09.pq)
# Processing file_3079 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/10.pq)
# Processing file_3081 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/11.pq)
# Processing file_3083 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/30s/wind/12.pq)
# Processing file_3085 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/1.pq)
# Processing file_3087 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/10.pq)
# Processing file_3089 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/11.pq)
# Processing file_3091 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/12.pq)
# Processing file_3093 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/13.pq)
# Processing file_3095 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/14.pq)
# Processing file_3097 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/15.pq)
# Processing file_3099 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/16.pq)
# Processing file_3101 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/17.pq)
# Processing file_3103 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/18.pq)
# Processing file_3105 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/19.pq)
# Processing file_3107 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/2.pq)
# Processing file_3109 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/3.pq)
# Processing file_3111 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/4.pq)
# Processing file_3113 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/5.pq)
# Processing file_3115 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/6.pq)
# Processing file_3117 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/7.pq)
# Processing file_3119 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/8.pq)
# Processing file_3121 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/bio/9.pq)
# Processing file_3123 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/elev/elev.pq)
# Processing file_3125 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/01.pq)
# Processing file_3127 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/02.pq)
# Processing file_3129 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/03.pq)
# Processing file_3131 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/04.pq)
# Processing file_3133 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/05.pq)
# Processing file_3135 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/06.pq)
# Processing file_3137 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/07.pq)
# Processing file_3139 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/08.pq)
# Processing file_3141 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/09.pq)
# Processing file_3143 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/10.pq)
# Processing file_3145 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/11.pq)
# Processing file_3147 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/prec/12.pq)
# Processing file_3149 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/01.pq)
# Processing file_3151 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/02.pq)
# Processing file_3153 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/03.pq)
# Processing file_3155 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/04.pq)
# Processing file_3157 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/05.pq)
# Processing file_3159 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/06.pq)
# Processing file_3161 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/07.pq)
# Processing file_3163 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/08.pq)
# Processing file_3165 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/09.pq)
# Processing file_3167 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/10.pq)
# Processing file_3169 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/11.pq)
# Processing file_3171 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/srad/12.pq)
# Processing file_3173 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/01.pq)
# Processing file_3175 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/02.pq)
# Processing file_3177 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/03.pq)
# Processing file_3179 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/04.pq)
# Processing file_3181 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/05.pq)
# Processing file_3183 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/06.pq)
# Processing file_3185 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/07.pq)
# Processing file_3187 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/08.pq)
# Processing file_3189 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/09.pq)
# Processing file_3191 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/10.pq)
# Processing file_3193 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/11.pq)
# Processing file_3195 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tavg/12.pq)
# Processing file_3197 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/01.pq)
# Processing file_3199 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/02.pq)
# Processing file_3201 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/03.pq)
# Processing file_3203 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/04.pq)
# Processing file_3205 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/05.pq)
# Processing file_3207 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/06.pq)
# Processing file_3209 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/07.pq)
# Processing file_3211 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/08.pq)
# Processing file_3213 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/09.pq)
# Processing file_3215 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/10.pq)
# Processing file_3217 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/11.pq)
# Processing file_3219 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmax/12.pq)
# Processing file_3221 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/01.pq)
# Processing file_3223 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/02.pq)
# Processing file_3225 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/03.pq)
# Processing file_3227 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/04.pq)
# Processing file_3229 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/05.pq)
# Processing file_3231 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/06.pq)
# Processing file_3233 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/07.pq)
# Processing file_3235 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/08.pq)
# Processing file_3237 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/09.pq)
# Processing file_3239 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/10.pq)
# Processing file_3241 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/11.pq)
# Processing file_3243 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/tmin/12.pq)
# Processing file_3245 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/01.pq)
# Processing file_3247 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/02.pq)
# Processing file_3249 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/03.pq)
# Processing file_3251 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/04.pq)
# Processing file_3253 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/05.pq)
# Processing file_3255 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/06.pq)
# Processing file_3257 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/07.pq)
# Processing file_3259 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/08.pq)
# Processing file_3261 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/09.pq)
# Processing file_3263 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/10.pq)
# Processing file_3265 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/11.pq)
# Processing file_3267 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/vapr/12.pq)
# Processing file_3269 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/01.pq)
# Processing file_3271 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/02.pq)
# Processing file_3273 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/03.pq)
# Processing file_3275 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/04.pq)
# Processing file_3277 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/05.pq)
# Processing file_3279 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/06.pq)
# Processing file_3281 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/07.pq)
# Processing file_3283 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/08.pq)
# Processing file_3285 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/09.pq)
# Processing file_3287 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/10.pq)
# Processing file_3289 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/11.pq)
# Processing file_3291 (/user/bdm/persistent/worldclim/2.1/2022-06-02_11-35-08/5m/wind/12.pq)
#                   id       file relatedattr             label comment
# 0        attribute_0     file_0        None            gbifid    None
# 1        attribute_1     file_0        None        datasetkey    None
# 2        attribute_2     file_0        None      occurrenceid    None
# 3        attribute_3     file_0        None           kingdom    None
# 4        attribute_4     file_0        None            phylum    None
# ...              ...        ...         ...               ...     ...
# 5101  attribute_5101  file_3287        None       proj_raster    None
# 5102  attribute_5102  file_3289        None  proj_raster_path    None
# 5103  attribute_5103  file_3289        None       proj_raster    None
# 5104  attribute_5104  file_3291        None  proj_raster_path    None
# 5105  attribute_5105  file_3291        None       proj_raster    None
#
# [5106 rows x 5 columns]

# %%
# List PostgreSQL columns (attribute.csv: id,table,datatype,originalAttr,foreignKey,label,comment)

psql_url = "jdbc:postgresql://localhost:5432/species_rasters"
psql_driver = "org.postgresql.Driver"
psql_user = "postgres"
psql_password = "postgres"

tables = ["background", "samples"]
orig_attrs = {
    "species": "file_3", # Null for background
    "longitude": "file_3", # Null for background
    "latitude": "file_3", # Null for background
    "tmin": "file_3035",
    "tmax": "file_3011",
    "tavg": "file_2987",
    "prec": "file_2939",
    "srad": "file_2963",
    "wind": "file_3083",
    "vapr": "file_3059",
    "bio": "file_2913",
    "elev": "file_2915",
    "SRTM_RAMP2_TOPO": "file_268",
    "MOD_LSTD_M": "file_268",
}

col_comments = {
    "species": "Name of the species of interest or 'background'",
    "longitude": "Latitude (WGS 84)",
    "latitude": "Longitude (WGS 84)",
    "tmin": "Minimum temperature (°C) from WorldClim",
    "tmax": "Maximum temperature (°C) from WorldClim",
    "tavg": "Average temperature (°C) from WorldClim",
    "prec": "Precipitation (mm) from WorldClim",
    "srad": "Solar radiation (kJ m^{-2} day^{-1}) from WorldClim",
    "wind": "Wind speed (m s^{-1}) from WorldClim",
    "vapr": "Water vapor pressure (kPa) from WorldClim",
    "bio": "Mean Temperature of Driest Quarter from WorldClim",
    "elev": "Elevation from WorldClim",
    "SRTM_RAMP2_TOPO": "Topography from NEO",
    "MOD_LSTD_M": "Montly Land Surface Temperature [day] from NEO",
}


columns = []
colIdGen = ("column_" + str(c) for c in count())

for table in tables:
    print("Reading from PostgreSQL: " + table)
    df = (spark.read.format("jdbc")
        .option("url", psql_url)
        .option("driver", psql_driver)
        .option("user", psql_user)
        .option("password", psql_password)
        .option("dbtable", table)
        .load()
    )
    for col, dtype in df.dtypes:
        originalAttr = orig_attrs[col]
        if table == 'background' and col in ["species", "longitude", "latitude"]:
            originalAttr = None
        columns.append({
            "id": colIdGen.__next__(),
            "table": table,
            "datatype": dtype,
            "originalAttr": originalAttr,
            "foreignKey": None,
            "label": col,
            "comment": col_comments[col],
        })
        
columns_df = pd.DataFrame(data=columns)
columns_df.to_csv("data/column.csv", index=False, header=True)
columns_df
# Out:
# Reading from PostgreSQL: background
# Reading from PostgreSQL: samples
#            id       table datatype originalAttr foreignKey            label  \
# 0    column_0  background   string         None       None          species
# 1    column_1  background   string         None       None        longitude
# 2    column_2  background   string         None       None         latitude
# 3    column_3  background   string    file_3035       None             tmin
# 4    column_4  background   string    file_3011       None             tmax
# 5    column_5  background   string    file_2987       None             tavg
# 6    column_6  background   string    file_2939       None             prec
# 7    column_7  background   string    file_2963       None             srad
# 8    column_8  background   string    file_3083       None             wind
# 9    column_9  background   string    file_3059       None             vapr
# 10  column_10  background   string    file_2913       None              bio
# 11  column_11  background   string    file_2915       None             elev
# 12  column_12  background   string     file_268       None  SRTM_RAMP2_TOPO
# 13  column_13  background   string     file_268       None       MOD_LSTD_M
# 14  column_14     samples   string       file_3       None          species
# 15  column_15     samples    float       file_3       None        longitude
# 16  column_16     samples    float       file_3       None         latitude
# 17  column_17     samples    float    file_3035       None             tmin
# 18  column_18     samples    float    file_3011       None             tmax
# 19  column_19     samples    float    file_2987       None             tavg
# 20  column_20     samples    float    file_2939       None             prec
# 21  column_21     samples    float    file_2963       None             srad
# 22  column_22     samples    float    file_3083       None             wind
# 23  column_23     samples    float    file_3059       None             vapr
# 24  column_24     samples    float    file_2913       None              bio
# 25  column_25     samples    float    file_2915       None             elev
# 26  column_26     samples    float     file_268       None  SRTM_RAMP2_TOPO
# 27  column_27     samples    float     file_268       None       MOD_LSTD_M
#
#                                               comment
# 0     Name of the species of interest or 'background'
# 1                                   Latitude (WGS 84)
# 2                                  Longitude (WGS 84)
# 3             Minimum temperature (°C) from WorldClim
# 4             Maximum temperature (°C) from WorldClim
# 5             Average temperature (°C) from WorldClim
# 6                   Precipitation (mm) from WorldClim
# 7   Solar radiation (kJ m^{-2} day^{-1}) from Worl...
# 8                Wind speed (m s^{-1}) from WorldClim
# 9           Water vapor pressure (kPa) from WorldClim
# 10  Mean Temperature of Driest Quarter from WorldClim
# 11                           Elevation from WorldClim
# 12                                Topography from NEO
# 13     Montly Land Surface Temperature [day] from NEO
# 14    Name of the species of interest or 'background'
# 15                                  Latitude (WGS 84)
# 16                                 Longitude (WGS 84)
# 17            Minimum temperature (°C) from WorldClim
# 18            Maximum temperature (°C) from WorldClim
# 19            Average temperature (°C) from WorldClim
# 20                  Precipitation (mm) from WorldClim
# 21  Solar radiation (kJ m^{-2} day^{-1}) from Worl...
# 22               Wind speed (m s^{-1}) from WorldClim
# 23          Water vapor pressure (kPa) from WorldClim
# 24  Mean Temperature of Driest Quarter from WorldClim
# 25                           Elevation from WorldClim
# 26                                Topography from NEO
# 27     Montly Land Surface Temperature [day] from NEO
